# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df=pd.read_csv(r'C:\Users\Saravanan\OneDrive\Desktop\Machine Learning\Clustering\Customer-Data - 2.csv')

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['MINIMUM_PAYMENTS'].fillna('0',inplace=True)

# %%
df.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.histplot(df['BALANCE'])
plt.show()

# %%
sns.barplot(x='TENURE',y='PURCHASES',data=df)
plt.show()

# %%
df.hist(figsize=(16,12),bins=30,color='red',edgecolor='black')
plt.suptitle("Histograms for Numerical Features")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df['BALANCE'])
plt.title('Distribution of Balance')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='TENURE', data=df, palette='viridis')
plt.title('Distribution of TENURE')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='BALANCE', y='PURCHASES', data=df)
plt.title('Scatter plot: BALANCE vs PURCHASES')
plt.show()

# %%
sns.pairplot(df[['BALANCE', 'PURCHASES', 'ONEOFF_PURCHASES', 'CASH_ADVANCE']])
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()

# %%
# Identifying outliers in 'BALANCE' using the IQR method
Q1 = df['BALANCE'].quantile(0.25)
Q3 = df['BALANCE'].quantile(0.75)
IQR = Q3 - Q1

# Define outliers as points beyond 1.5 * IQR from the quartiles
outliers = df[(df['BALANCE'] < (Q1 - 1.5 * IQR)) | (df['BALANCE'] > (Q3 + 1.5 * IQR))]

print(f"Number of outliers in 'BALANCE': {len(outliers)}")
# Out:
# Number of outliers in 'BALANCE': 695

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='TENURE', y='BALANCE', data=df, palette='viridis')
plt.title('BALANCE Distribution Across TENURE Categories')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='TENURE', y='PURCHASES', data=df, palette='coolwarm')
plt.title('PURCHASES Distribution Across TENURE Categories')
plt.show()
