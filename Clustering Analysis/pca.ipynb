# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = {
    'Maths': [85, 88, 90, 70, 65],
    'Science': [80, 85, 88, 68, 60],
    'English': [78, 82, 85, 72, 65]
}
df=pd.DataFrame(data)
df
# Out:
#    Maths  Science  English
# 0     85       80       78
# 1     88       85       82
# 2     90       88       85
# 3     70       68       72
# 4     65       60       65

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
scaled_data
# Out:
# array([[ 0.5330101 ,  0.35881005,  0.22308455],
#        [ 0.82912682,  0.83092853,  0.78079594],
#        [ 1.02653797,  1.11419962,  1.19907948],
#        [-0.94757351, -0.77427431, -0.61348253],
#        [-1.44110138, -1.52966389, -1.58947745]])

# %%
pca=PCA(n_components=2)

principal_components=pca.fit_transform(scaled_data)

pca_df=pd.DataFrame(principal_components,columns=['PC1','PC2'])

pca_df
# Out:
#         PC1       PC2
# 0  0.643583  0.219851
# 1  1.409276  0.033824
# 2  1.928270 -0.121218
# 3 -1.348221 -0.236764
# 4 -2.632908  0.104306

# %%
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.9912257  0.00874062]

# %%
plt.scatter(pca_df['PC1'], pca_df['PC2'], color='blue')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Visualization')
plt.show()
